# %%
import HAL

# %%
from HAL.metrika import Plotter
from HAL.pixels import Color

# %%
pie_data = {
    "Apples": 30,
    "Bananas": 20,
    "Cherries": 15,
    "Grapes": 25,
    "Oranges": 10
}

plotter = Plotter()
plotter.plot_pie_chart(pie_data, start_angle=90)

# %%
plotter = Plotter(scale=150, width=3000)

data = {
    "Journalists": 4.5,
    "Police Officers": 4.0,
    "Teachers": 3.8,
    "Plumbers": 3.6,
    "Nurses": 3.5,
    "Company Executives": 3.4,
    "Telesales": 3.3,
    "IT Technical Support": 3.2,
    "Retail Staff": 3.1,
    "Drivers": 3.0,
    "Scientists": 5,
    "PR Professionals": 4,
    "School Administrators": 4,
    "Writers & Editors": 3,
    "Food Preparers": 3,
    "Nurses": 3,
    "Teachers": 2,
    "Lab Technicians": 2,
    "Marketing Professionals": 2,
    "Finance Professionals": 2
}

plotter.plot_histogram(data,
                       horizontal_lines_interval = 2, label_size=20)

# %%
import math

pie_data = {
    "Apples": 30,
    "Bananas": 20,
    "Cherries": 15,
    "Grapes": 25,
    "Oranges": 10
}

f = lambda x: math.exp(math.sin(x**2))
g = lambda x: -math.exp(math.sin(x**2))

plotter = Plotter()
plotter.draw_axes(gridlines=True, grid_spacing=2, show_labels = True)
plotter.plot(f)
plotter.plot(g)
plotter.picture.image
# Out:
# <PIL.Image.Image image mode=RGB size=2000x2000>
